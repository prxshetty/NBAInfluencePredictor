# %%
import pandas as pd
nba=pd.read_csv("data/nba_2023_2024_ps.csv")

# %%
nba.head()
# Out:
#    Rk            Player   Pos  Age   Tm   G  GS    MP   FG   FGA  ...  ORB  \
# 0   1  Precious Achiuwa  PF-C   24  TOT  53  14  22.5  3.3   6.8  ...  2.7
# 1   1  Precious Achiuwa     C   24  TOR  25   0  17.5  3.1   6.8  ...  2.0
# 2   1  Precious Achiuwa    PF   24  NYK  28  14  26.9  3.5   6.8  ...  3.3
# 3   2       Bam Adebayo     C   26  MIA  49  49  34.6  7.7  15.1  ...  2.2
# 4   3      Ochai Agbaji    SG   23  TOT  59  10  18.9  2.1   4.8  ...  0.7
#
#    DRB   TRB  AST  STL  BLK  TOV   PF   PTS  Player-additional
# 0  3.9   6.6  1.4  0.6  0.8  1.1  1.9   8.0          achiupr01
# 1  3.4   5.4  1.8  0.6  0.5  1.2  1.6   7.7          achiupr01
# 2  4.3   7.6  1.0  0.6  1.1  1.0  2.2   8.3          achiupr01
# 3  8.3  10.5  4.1  1.1  1.0  2.5  2.5  20.3          adebaba01
# 4  1.7   2.3  0.9  0.5  0.5  0.7  1.3   5.4          agbajoc01
#
# [5 rows x 31 columns]

# %%
nba.describe()
# Out:
#                Rk         Age           G          GS          MP          FG  \
# count  679.000000  679.000000  679.000000  679.000000  679.000000  679.000000
# mean   270.547865   26.159057   31.932253   14.412371   18.053756    2.963770
# std    160.892359    4.374238   19.662975   19.574927   10.107631    2.443246
# min      1.000000   19.000000    1.000000    0.000000    0.500000    0.000000
# 25%    132.500000   23.000000   13.000000    0.000000    9.500000    1.100000
# 50%    276.000000   25.000000   35.000000    3.000000   17.200000    2.200000
# 75%    408.500000   29.000000   50.000000   26.000000   26.850000    4.350000
# max    548.000000   39.000000   61.000000   61.000000   37.800000   11.800000
#
#               FGA         FG%          3P         3PA  ...         FT%  \
# count  679.000000  665.000000  679.000000  679.000000  ...  611.000000
# mean     6.395287    0.446723    0.914138    2.565832  ...    0.750183
# ...
